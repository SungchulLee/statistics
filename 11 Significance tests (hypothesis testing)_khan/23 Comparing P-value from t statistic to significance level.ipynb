# %% [markdown]
# [khanacademy](https://www.khanacademy.org/math/ap-statistics/tests-significance-ap/one-sample-t-test-mean/v/comparing-p-value-from-t-statistic-to-significance-level?modal=1)

# %% [markdown]
# <div align="center"><img src="img/Screen Shot 2019-08-13 at 11.10.33 PM.png" width="100%" height="30%"></div>
# <div align="center"><img src="img/Screen Shot 2019-08-13 at 11.11.07 PM.png" width="100%" height="30%"></div>
